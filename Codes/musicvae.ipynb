# %% [markdown]
# # Music VAE, Groove MIDI Dataset을 이용하여 4마디에 해당하는 드럼 샘플을 뽑아내는 과정을 수행

# %% [markdown]
# ### Install

# %%
# !pip install magenta==2.1.0
# Out:
# ...
#   Using cached magenta-2.1.0-py3-none-any.whl (1.4 MB)
# ...
#   Using cached sox-1.4.1-py2.py3-none-any.whl (39 kB)
# ...
#   Using cached Pillow-9.4.0-cp39-cp39-win_amd64.whl (2.5 MB)
# ...
#   Using cached python-rtmidi-1.1.2.tar.gz (204 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached note_seq-0.0.5-py3-none-any.whl (209 kB)
# ...
#   Using cached tensorflow_datasets-4.8.2-py3-none-any.whl (5.3 MB)
# ...
#   Using cached dm_sonnet-2.0.1-py3-none-any.whl (268 kB)
# ...
#   Using cached mido-1.2.6-py2.py3-none-any.whl (69 kB)
# ...
#   Using cached tensorflow_probability-0.19.0-py2.py3-none-any.whl (6.7 MB)
# ...
#   Using cached numba-0.49.1.tar.gz (2.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pretty_midi-0.2.9-py3-none-any.whl
# ...
#   Using cached tensor2tensor-1.15.7-py2.py3-none-any.whl (1.4 MB)
# ...
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# ...

# %% [markdown]
# ### Import Library

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from magenta.scripts.convert_dir_to_note_sequences import convert_directory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 import numpy as np
#       3 import pandas as pd
# ----> 5 from magenta.scripts.convert_dir_to_note_sequences import convert_directory
#
# ModuleNotFoundError: No module named 'magenta'

# %% [markdown]
# ### Hyper_parameters

# %%
# Local
DATA_DIR = 'C:/Users/ddoub/OneDrive/Desktop/musicvae/Dataset/groove-v1.0.0-midionly/groove/'
TFRECORD_DIR = 'C:/Users/ddoub/OneDrive/Desktop/musicvae/Tfrecord/'

# %% [markdown]
# ### Data Load

# %%
info_csv = pd.read_csv(DATA_DIR + 'info.csv')
info_csv.head()
# Out:
#        drummer                session                        id  \
# 0     drummer1  drummer1/eval_session   drummer1/eval_session/1
# 1     drummer1  drummer1/eval_session  drummer1/eval_session/10
# 2     drummer1  drummer1/eval_session   drummer1/eval_session/2
# 3     drummer1  drummer1/eval_session   drummer1/eval_session/3
# 4     drummer1  drummer1/eval_session   drummer1/eval_session/4
# ...        ...                    ...                       ...
# 1145  drummer2      drummer2/session2      drummer2/session2/11
# 1146  drummer2      drummer2/session2      drummer2/session2/12
# 1147  drummer2      drummer2/session2      drummer2/session2/13
# 1148  drummer2      drummer2/session2      drummer2/session2/14
# 1149  drummer2      drummer2/session2      drummer2/session2/15
#
#               style  bpm beat_type time_signature  \
# 0      funk/groove1  138      beat            4-4
# 1     soul/groove10  102      beat            4-4
# ...

# %% [markdown]
# ## 1. Preprocessing

# %%
convert_directory(data_root,tfrec_root,recursive=True)

# %% [markdown]
# ## 2. Train Model

# %% [markdown]
# ## Test Model

# %% [markdown]
# ## 3. Gen
